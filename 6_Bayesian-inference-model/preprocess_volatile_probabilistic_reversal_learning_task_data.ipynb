# %% [markdown]
# # データのアップロード
#
# 以下の①から④の手順でデータをアップロードします。

# %% [markdown]
# ![Screenshot 2025-03-19 at 22.36.36.png](data:image/png;base64,...)

# %% [markdown]
# ## 前処理
#
# CBATのデモを実施した際に出力されるcsvファイルを読み込んで、解析可能な用に前処理をします。

# %%
import pandas as pd

# CSVを読み込む
df = pd.read_csv("data.csv")
df.head()
